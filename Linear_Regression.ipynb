# %% [markdown]
# <a href="https://colab.research.google.com/github/YuLim2/NOTIFAM/blob/master/%08Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("2101.csv", encoding='CP949')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        경락일자            경매시간          시장명  ... 거래량 Unnamed: 7  Unnamed: 8
# 0  2021.1.2  2021.1.2 12:58  부산국제수산물도매시장  ...  20        NaN         NaN
# 1  2021.1.2  2021.1.2 12:58  부산국제수산물도매시장  ...  37        NaN         NaN
# 2  2021.1.2  2021.1.2 12:58  부산국제수산물도매시장  ...  10        NaN         NaN
# 3  2021.1.2  2021.1.2 10:01  부산국제수산물도매시장  ...   1        NaN         NaN
# 4  2021.1.2  2021.1.2 10:01  부산국제수산물도매시장  ...   1        NaN         NaN
#
# [5 rows x 9 columns]

# %%
tomato.head()
# Out:
#          경락일자           경매시간           시장명  ... 거래량 Unnamed: 7  Unnamed: 8
# 224  2021.1.2  2021.1.2 8:07  광주서부농수산물도매시장  ...  16        NaN         NaN
# 225  2021.1.2  2021.1.2 8:07  광주서부농수산물도매시장  ...  11        NaN         NaN
# 226  2021.1.2  2021.1.2 8:08  광주서부농수산물도매시장  ...  10        NaN         NaN
# 227  2021.1.2  2021.1.2 8:08  광주서부농수산물도매시장  ...  14        NaN         NaN
# 228  2021.1.2  2021.1.2 8:08  광주서부농수산물도매시장  ...  13        NaN         NaN
#
# [5 rows x 9 columns]

# %%
tomatoMany = np.array(tomato.iloc[: , 4])
tomatoPrice = np.array(tomato.iloc[: , 5])
tomatoEachPrice = []
for i in range(0, len(tomatoMany)):
  tomatoEachPrice = float(tomatoPrice[i])/float(tomatoMany[i])
  print(tomatoEachPrice, end=",")
# Out:
# 2850.0,2600.0,2400.0,1850.0,1350.0,1700.0,1700.0,2700.0,3600.0,3600.0,3500.0,2800.0,1900.0,2700.0,2400.0,2100.0,2390.0,2390.0,2000.0,1700.0,1500.0,2520.0,2520.0,2520.0,2520.0,2580.0,2580.0,2510.0,2370.0,2530.0,1120.0,2630.0,2630.0,2410.0,2120.0,1530.0,1220.0,1710.0,1710.0,2920.0,800.0,2960.0,2560.0,2310.0,2020.0,1430.0,1780.0,1510.0,1000.0,3000.0,2900.0,2780.0,2490.0,2250.0,1530.0,900.0,1440.0,2430.0,2430.0,2330.0,2000.0,1330.0,1600.0,1600.0,2200.0,2000.0,1830.0,1330.0,2410.0,2520.0,2550.0,2180.0,1330.0,1130.0,2600.0,2480.0,2360.0,2240.0,1240.0,2240.0,2240.0,2160.0,2400.0,2000.0,3500.0,3250.0,2700.0,2600.0,1600.0,1200.0,1100.0,600.0,1800.0,1700.0,2000.0,2000.0,1300.0,1900.0,4400.0,3000.0,1800.0,1700.0,1900.0,1900.0,2000.0,2800.0,1600.0,1900.0,1900.0,1800.0,1200.0,2400.0,1900.0,1900.0,600.0,600.0,1700.0,1400.0,1400.0,1700.0,1900.0,1800.0,600.0,1700.0,1200.0,1600.0,1200.0,1800.0,1800.0,2000.0,1600.0,1700.0,1900.0,1800.0,2000.0,1500.0,1000.0,1000.0,2000.0,1900.0,2000.0,1200.0,1900.0,170
# ...

# %%
tomatoDay = np.array(tomato.iloc[: , 0])
for i in range(0, len(tomatoDay)):
  tomatoDay = float(tomatoDay[i])
  print(tomatoDay1, end=",")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-c462061ebc79> in <module>()
#       1 tomatoDay = np.array(tomato.iloc[: , 0])
#       2 for i in range(0, len(tomatoDay)):
# ----> 3   tomatoDay1 = float(tomatoDay[i])
#       4   print(tomatoDay1, end=",")
#
# ValueError: could not convert string to float: '2021.1.2'

# %%
x = tomatoDay
y = tomatoEachPrice
plt.plot(x, y, 'o')<br>plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-75d73fcfb941> in <module>()
#       1 x = tomatoDay
#       2 y = tomatoEachPrice
# ----> 3 plt.plot(x, y, 'o')<br>plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...
